# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv("/content/student.csv")
df
# Out:
#       Student_ID  Study_Hours_Per_Day  Extracurricular_Hours_Per_Day  \
# 0              1                  6.9                            3.8
# 1              2                  5.3                            3.5
# 2              3                  5.1                            3.9
# 3              4                  6.5                            2.1
# 4              5                  8.1                            0.6
# ...          ...                  ...                            ...
# 1095        1096                  8.4                            2.7
# 1096        1097                  5.2                            1.8
# 1097        1098                  8.4                            3.9
# 1098        1099                  6.2                            3.2
# 1099        1100                  8.2                            1.7
#
#       Sleep_Hours_Per_Day  Social_Hours_Per_Day  \
# 0                     8.7                   2.8
# ...

# %%
sns.distplot(df['Study_Hours_Per_Day'].dropna())
# Out:
# /tmp/ipython-input-486207067.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Study_Hours_Per_Day'].dropna())
# <Axes: xlabel='Study_Hours_Per_Day', ylabel='Density'>

# %%
sns.distplot(df['Extracurricular_Hours_Per_Day'].dropna())
# Out:
# /tmp/ipython-input-1329306143.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Extracurricular_Hours_Per_Day'].dropna())
# <Axes: xlabel='Extracurricular_Hours_Per_Day', ylabel='Density'>

# %%
sns.distplot(df['Sleep_Hours_Per_Day'].dropna())
# Out:
# /tmp/ipython-input-1605259958.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Sleep_Hours_Per_Day'].dropna())
# <Axes: xlabel='Sleep_Hours_Per_Day', ylabel='Density'>

# %%
sns.distplot(df['Social_Hours_Per_Day'].dropna())
# Out:
# /tmp/ipython-input-3634851699.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Social_Hours_Per_Day'].dropna())
# <Axes: xlabel='Social_Hours_Per_Day', ylabel='Density'>

# %%
sns.distplot(df['Physical_Activity_Hours_Per_Day'].dropna())
# Out:
# /tmp/ipython-input-1911220118.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Physical_Activity_Hours_Per_Day'].dropna())
# <Axes: xlabel='Physical_Activity_Hours_Per_Day', ylabel='Density'>

# %%
sns.distplot(df['GPA'].dropna())
# Out:
# /tmp/ipython-input-4286665249.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['GPA'].dropna())
# <Axes: xlabel='GPA', ylabel='Density'>

# %%
sns.distplot(df['anxiety_level'].dropna())
# Out:
# /tmp/ipython-input-1385790808.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['anxiety_level'].dropna())
# <Axes: xlabel='anxiety_level', ylabel='Density'>

# %%
sns.distplot(df['self_esteem'].dropna())
# Out:
# /tmp/ipython-input-2193633366.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['self_esteem'].dropna())
# <Axes: xlabel='self_esteem', ylabel='Density'>

# %%
sns.distplot(df['mental_health_history'].dropna())
# Out:
# /tmp/ipython-input-507486787.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['mental_health_history'].dropna())
# <Axes: xlabel='mental_health_history', ylabel='Density'>

# %%
sns.distplot(df['depression'].dropna())
# Out:
# /tmp/ipython-input-644805606.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['depression'].dropna())
# <Axes: xlabel='depression', ylabel='Density'>

# %%
sns.distplot(df['headache'].dropna())
# Out:
# /tmp/ipython-input-440264760.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['headache'].dropna())
# <Axes: xlabel='headache', ylabel='Density'>

# %%
sns.distplot(df['blood_pressure'].dropna())
# Out:
# /tmp/ipython-input-138967835.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['blood_pressure'].dropna())
# <Axes: xlabel='blood_pressure', ylabel='Density'>

# %%
sns.distplot(df['breathing_problem'].dropna())
# Out:
# /tmp/ipython-input-4294542885.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['breathing_problem'].dropna())
# <Axes: xlabel='breathing_problem', ylabel='Density'>

# %%
sns.distplot(df['noise_level'].dropna())
# Out:
# /tmp/ipython-input-1846151745.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['noise_level'].dropna())
# <Axes: xlabel='noise_level', ylabel='Density'>

# %%
sns.distplot(df['living_conditions'].dropna())
# Out:
# /tmp/ipython-input-2240894052.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['living_conditions'].dropna())
# <Axes: xlabel='living_conditions', ylabel='Density'>

# %%
sns.distplot(df['academic_performance'].dropna())
# Out:
# /tmp/ipython-input-519130555.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['academic_performance'].dropna())
# <Axes: xlabel='academic_performance', ylabel='Density'>

# %%
sns.distplot(df['study_load'].dropna())
# Out:
# /tmp/ipython-input-1486895549.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['study_load'].dropna())
# <Axes: xlabel='study_load', ylabel='Density'>

# %%
sns.distplot(df['teacher_student_relationship'].dropna())
# Out:
# /tmp/ipython-input-1322550374.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['teacher_student_relationship'].dropna())
# <Axes: xlabel='teacher_student_relationship', ylabel='Density'>

# %%
sns.distplot(df['future_career_concerns'].dropna())
# Out:
# /tmp/ipython-input-2646956661.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['future_career_concerns'].dropna())
# <Axes: xlabel='future_career_concerns', ylabel='Density'>

# %%
sns.distplot(df['social_support'].dropna())
# Out:
# /tmp/ipython-input-2946910623.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['social_support'].dropna())
# <Axes: xlabel='social_support', ylabel='Density'>

# %%
sns.distplot(df['peer_pressure'].dropna())
# Out:
# /tmp/ipython-input-1167902467.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['peer_pressure'].dropna())
# <Axes: xlabel='peer_pressure', ylabel='Density'>

# %%
sns.distplot(df['extracurricular_activities'].dropna())
# Out:
# /tmp/ipython-input-953960073.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['extracurricular_activities'].dropna())
# <Axes: xlabel='extracurricular_activities', ylabel='Density'>

# %%
sns.distplot(df['bullying'].dropna())
# Out:
# /tmp/ipython-input-3765772410.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['bullying'].dropna())
# <Axes: xlabel='bullying', ylabel='Density'>

# %%
sns.countplot(x='Stress_Level', data=df)
# Out:
# <Axes: xlabel='Stress_Level', ylabel='count'>
